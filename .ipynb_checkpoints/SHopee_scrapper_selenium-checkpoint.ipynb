# %%
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
from selenium import webdriver
import time

from datetime import datetime
from datetime import date

today = date.today()
# Month abbreviation, day and year	
date_str = today.strftime("%d%b%y")
now = datetime.now()
# dd/mm/YY H:M:S
time_str = now.strftime("%H%M")

driver = webdriver.Firefox()

keyword ='mie ashitaki'
keysearch = keyword.replace(' ', '%20')
market_place = "shopee"
print(keyword + "_" + market_place + "_" + date_str + "_" + time_str)
print(keysearch)
# Out:
# mie ashitaki_shopee_15Jan23_2117
# mie%20ashitaki

# %%
#driver.get('https://www.tokopedia.com/search?navsource=&ob=5&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&q=arduino')
driver.get('https://shopee.co.id/search?keyword=' + keysearch )
    
counter_page = 0
datas = []
time.sleep(5)
print("Ready")
# Out:
# Ready

# %%
now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time Start =", current_time)

while counter_page < 12:
    for _ in range(0, 6500, 500):
        time.sleep(0.5)
        driver.execute_script("window.scrollBy(0,500)")
        
    elements = driver.find_elements(by=By.CLASS_NAME, value='tWpFe2')
    for element in elements: 
        try:
            img_url = element.find_element(by=By.CLASS_NAME, value='yvbeD6 KUUypf').get_attribute('src')
        except NoSuchElementException:
            img_url = '0'
        try:
            product_name = element.find_element(by=By.CLASS_NAME, value='dpiR4u').text
        except NoSuchElementException:
            product_name = '0'
        try:
            price = element.find_element(by=By.CLASS_NAME, value='hpDKMN').text            
        except NoSuchElementException:
            price = '0'
        try:
            city = element.find_element(by=By.CLASS_NAME, value='zGGwiV').text
        except NoSuchElementException:
            city = '0'
        
        try:
            rating = ''#element.find_element(by=By.CLASS_NAME, value='shopee-rating-stars__star-wrapper').text
        except NoSuchElementException:
            rating = '0'
        try:
            #url_text = driver.find_element(by=By.CLASS_NAME, value='col-xs-2-4 shopee-search-item-result__item').text

            url = ''#element.find_element(by=By.CLASS_NAME, value='col-xs-2-4 shopee-search-item-result__item').text
        except NoSuchElementException:
            url = '0'
        
        try:
            quantity_sold = element.find_element(by=By.CLASS_NAME, value='ZnrnMl').text
        except NoSuchElementException:
            quantity_sold = '0'
           
        try:
            #shop_name_text = element.find_element(by=By.CLASS_NAME, value='css-1rn0irl').text
            #shop_name = (shop_name_text.split('\n'))
            #shop_name = shop_name[1]
            shop_name =""
        except NoSuchElementException:
            shop_name = '0'
        
        #presentase_diskon = element.find_element(by=By.CLASS_NAME, value='css-1qtulwh').text
        #print([price + " - " + (city) + " - " + (shop_name)])
        datas.append({
            'img_url': img_url,
            'product_name': product_name,
            'price': price,
            'city': city,
            'location': city,
            'rating': rating,
            'url': url,
            'quantity_sold': quantity_sold,
            'shop_name': shop_name
            #'presentase_diskon': presentase_diskon
        })
    counter_page += 1
    try:
        #next_page = driver.find_element(by=By.XPATH, value="//button[@class='css-1ix4b60-unf-pagination-item' and text()='" + str(counter_page + 1) + "']")
        next_page = driver.find_element(by=By.XPATH, value="//button[@class='shopee-button-solid shopee-button-solid--primary' and text()='" + str(counter_page + 1) + "']")
        next_page.click()
    except NoSuchElementException:
        pass
                
print("finish...")
now = datetime.now()
current_time = now.strftime("%H:%M:%S")
print("Current Time Stop=", current_time)
# Out:
# Current Time Start = 21:17:40

# %%
datas
# Out:
# [{'img_url': '0',
#   'product_name': 'Paket Ashitaki 2',
#   'price': 'Rp99.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '9 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Fitmee - FitMee BAYAM / (Shirataki Noodle) Low Calorie Mie Diet Bebas Kolestrol, Rendah Gula dan Tinggi Serat',
#   'price': 'Rp18.500\nRp18.250',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,8RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Goreng Original 75gr - Mie Tanpa Pengawet\nPilih 3, diskon 3%',
#   'price': 'Rp24.900\nRp23.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,3RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Rebus Soto 75gr - Mie Rendah Kalori\nPilih 3, diskon 3%',
#   'price': 'Rp24.900\nRp23.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,9RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Soto - Goreng Original - Goreng ala Jepang',
#   'price': 'Rp19.240',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN\nCashback 50%',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '3,6RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki mie Rendah Kalori',
#   'price': 'Rp20.000\nRp18.800',
#   'city': 'KOTA DEPOK',
#   'location': 'KOTA DEPOK',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mie Rendah Kalori Shirataki Tanpa Pengawet Mi Goreng Jepang Goreng Original',
#   'price': 'Rp19.053 - Rp39.572',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '90 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT ASHITABA | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp19.790 - Rp20.490',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '10RB+ Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mie Shirataki Diet Sehat | Shirataki Noodle Mie Instant',
#   'price': 'Rp25.000\nRp19.950',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '950 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE GORENG JEPANG ORIGINAL SOTO VEGAN KARI PEDAS BULGOGI CREAMY SAUCE SHIRATAKI ASHITABA MI SIRATAKI DIET KONYAKU NASI BERAS SIRATAKI PORANG BASAH KERING RICE NOODLE DEBM KETO PENURUN BERAT BADAN PELANGSING PRUNE PLUM CHIA SEED FITMEE FITME CIA\nPilih 3, diskon 1%',
#   'price': 'Rp30.000\nRp19.900',
#   'city': 'KOTA MADIUN',
#   'location': 'KOTA MADIUN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp18.499',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mie Low Callories Ashitaki Ashitaba Shirataki',
#   'price': 'Rp19.800',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '350 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Instan (Ashitaba & Shirataki)',
#   'price': 'Rp18.490 - Rp18.990',
#   'city': 'KOTA BANDUNG',
#   'location': 'KOTA BANDUNG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '10RB+ Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Shirataki Instant Diet',
#   'price': 'Rp24.999\nRp24.599',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '439 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Instan Ashitaba Shirataki 68 gram',
#   'price': 'Rp18.500',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '504 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Shirataki Rebus Soto / Kari Ayam - Instanst sehat NON MSG low carbo diet keto',
#   'price': 'Rp18.700',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mi Rebus Shirataki Soto - Diet Keto Non MSG',
#   'price': 'Rp18.780',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '196 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original 1 DUS ISI 12PCS (12x75gr)',
#   'price': 'Rp227.100',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '65 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Kari Ayam',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mie Shirataki - Mi Instan Diet Sehat - Ashitaba Konjac Noodle - Rendah Kalori',
#   'price': 'Rp19.900 - Rp20.400',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '283 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Tomyum',
#   'price': 'Rp22.000',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '56 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mie Instant Ashitaba Ashitaki',
#   'price': 'Rp19.500',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '88 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Rendang Shirataki Diet Rendah Kalori HALAL',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '86 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original (75gr)',
#   'price': 'Rp20.200',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Tom Yum 73gr - Mie Shirataki - Mie Diet - Rendah Kalori',
#   'price': 'Rp27.400\nRp23.900',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '50 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp19.878 - Rp20.278',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '281 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'FITMEE MIE SHIRATAKI GORENG KOREA SAPI SOTO CARBONARA AYAM BAWANG FITME MI SIRATAKI KONYAKU FIT MEE ME DIET KETO DEBM MAKANAN ASHITAKI CREAMY LATTE BERAS PORANG RICE KERING BASAH PENURUN BERAT BADAN PELANGSING PRUNES PRUNE PLUM CHIA SEED CIA TEH JATI CINA\nPilih 3, diskon 1%',
#   'price': 'Rp17.900 - Rp19.990',
#   'city': 'KOTA MADIUN',
#   'location': 'KOTA MADIUN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '579 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Ashitaba & Shirataki Mie Instan Rendah Kalori',
#   'price': 'Rp18.000 - Rp20.500',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '425 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mi Rebus Rasa Soto Ashitaki 69.5 g\nMurah Lebay',
#   'price': 'Rp22.900',
#   'city': 'KOTA JAKARTA SELATAN',
#   'location': 'KOTA JAKARTA SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '226 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original',
#   'price': 'Rp19.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '18 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Soto (1 Box)',
#   'price': 'Rp23.000\nRp17.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '558 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Rendang / Tomyum / Kari Ayam',
#   'price': 'Rp19.192 - Rp20.169',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '41 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Noodle / Mie Rendah Carbo / MIE DIET / RENDAH KALORI / MIE SEHAT / LOW FAT / TOM YUM TOMYUM TOMYAM TOM YAM SOTO RENDANG KARI ORIGINAL ALA JEPANG',
#   'price': 'Rp21.500 - Rp21.900',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki MI Goreng Ala Jepang 68 gr',
#   'price': 'Rp21.400\nRp19.000',
#   'city': 'KOTA BALIKPAPAN',
#   'location': 'KOTA BALIKPAPAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Instan Bulgogi 76 gr',
#   'price': 'Rp23.200\nRp19.300',
#   'city': 'KOTA BEKASI',
#   'location': 'KOTA BEKASI',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '168 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Fit mee Mie Shirataki Rasa Mie Goreng Korea',
#   'price': 'Rp15.350',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Rasa Soto',
#   'price': 'Rp19.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '17 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki (Ashitaba & Shirataki) Mi Kari Pedas - 75 g\nGrosir',
#   'price': 'Rp22.000',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '62 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Low Calori - Rendang',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '19 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': '[GROSIR!!] mie Ashitaki Rendah Kalori Diet\nGrosir',
#   'price': 'Rp20.000\nRp18.300',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE INSTAN ASHITABA SHIRATAKI MIE DIET',
#   'price': 'Rp23.000',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '283 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Low Calori - Creamy Sauce\nHadiah Gratis',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '15 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Tomyum Shirataki Mie',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '64 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Rasa Creamy Sauce',
#   'price': 'Rp21.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '12 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Ashitaba Mie Mi Shirataki Noodle Soto Goreng Original Jepang Kari Pedas Creamy Sauce Veggie Bulgogi Halal Diet Instan Sehat Low Rendah Carbo\nDiskon Rp50',
#   'price': 'Rp19.800',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,9RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie',
#   'price': 'Rp22.000',
#   'city': 'KOTA BANJARBARU',
#   'location': 'KOTA BANJARBARU',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Kari Pedas\nHadiah Gratis',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '16 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng/Rebus Instant with Chalcone / Mie Instan Shirataki',
#   'price': 'Rp20.000 - Rp20.500',
#   'city': 'KOTA YOGYAKARTA',
#   'location': 'KOTA YOGYAKARTA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '282 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Jepang 1 DUS ISI 12PCS (12x68gr)',
#   'price': 'Rp227.100',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '22 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original (1 Box)',
#   'price': 'Rp23.000\nRp17.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '426 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN HALAL PROMO BPOM',
#   'price': 'Rp18.499',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi veggie original 67gr- Mie Diet - Mie Tanpa Pengawet',
#   'price': 'Rp24.000',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '32 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mie Ashitaki Diet Rendah Kalori',
#   'price': 'Rp20.000\nRp18.500',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki/ Shirataki soto jepang veggie kari creamy Mug Cake mattcha , chocolate latte Low Callory',
#   'price': 'Rp4.500 - Rp24.000',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Wet Shirataki Noodle (Mie Shirataki Basah) Per-Dus/Carton',
#   'price': 'Rp190.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '189 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mr Ishii Mie Shirataki Basah (200 gr)',
#   'price': 'Rp10.999',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Konnyaku Blok (Shirataki Konnyaku Low Carbs-Ketogenic) 500Gram',
#   'price': 'Rp16.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '539 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Creamy Sauce 85gr (Mie Rendah Kalori)',
#   'price': 'Rp22.700',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '96 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original 75gr (Mie Rendah Kalori)',
#   'price': 'Rp22.700',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '247 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Paket Ashitaki 2',
#   'price': 'Rp99.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '9 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Fitmee - FitMee BAYAM / (Shirataki Noodle) Low Calorie Mie Diet Bebas Kolestrol, Rendah Gula dan Tinggi Serat',
#   'price': 'Rp18.500\nRp18.250',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,8RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Goreng Original 75gr - Mie Tanpa Pengawet\nPilih 3, diskon 3%',
#   'price': 'Rp24.900\nRp23.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,3RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Rebus Soto 75gr - Mie Rendah Kalori\nPilih 3, diskon 3%',
#   'price': 'Rp24.900\nRp23.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,9RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Soto - Goreng Original - Goreng ala Jepang',
#   'price': 'Rp19.240',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN\nCashback 50%',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '3,6RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki mie Rendah Kalori',
#   'price': 'Rp20.000\nRp18.800',
#   'city': 'KOTA DEPOK',
#   'location': 'KOTA DEPOK',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mie Rendah Kalori Shirataki Tanpa Pengawet Mi Goreng Jepang Goreng Original',
#   'price': 'Rp19.053 - Rp39.572',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '90 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT ASHITABA | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp19.790 - Rp20.490',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '10RB+ Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mie Shirataki Diet Sehat | Shirataki Noodle Mie Instant',
#   'price': 'Rp25.000\nRp19.950',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '950 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE GORENG JEPANG ORIGINAL SOTO VEGAN KARI PEDAS BULGOGI CREAMY SAUCE SHIRATAKI ASHITABA MI SIRATAKI DIET KONYAKU NASI BERAS SIRATAKI PORANG BASAH KERING RICE NOODLE DEBM KETO PENURUN BERAT BADAN PELANGSING PRUNE PLUM CHIA SEED FITMEE FITME CIA\nPilih 3, diskon 1%',
#   'price': 'Rp30.000\nRp19.900',
#   'city': 'KOTA MADIUN',
#   'location': 'KOTA MADIUN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp18.499',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mie Low Callories Ashitaki Ashitaba Shirataki',
#   'price': 'Rp19.800',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '350 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Instan (Ashitaba & Shirataki)',
#   'price': 'Rp18.490 - Rp18.990',
#   'city': 'KOTA BANDUNG',
#   'location': 'KOTA BANDUNG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '10RB+ Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Shirataki Instant Diet',
#   'price': 'Rp24.999\nRp24.599',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '439 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Instan Ashitaba Shirataki 68 gram',
#   'price': 'Rp18.500',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '504 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Shirataki Rebus Soto / Kari Ayam - Instanst sehat NON MSG low carbo diet keto',
#   'price': 'Rp18.700',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mi Rebus Shirataki Soto - Diet Keto Non MSG',
#   'price': 'Rp18.780',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '196 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original 1 DUS ISI 12PCS (12x75gr)',
#   'price': 'Rp227.100',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '65 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Kari Ayam',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mie Shirataki - Mi Instan Diet Sehat - Ashitaba Konjac Noodle - Rendah Kalori',
#   'price': 'Rp19.900 - Rp20.400',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '283 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Tomyum',
#   'price': 'Rp22.000',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '56 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mie Instant Ashitaba Ashitaki',
#   'price': 'Rp19.500',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '88 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Rendang Shirataki Diet Rendah Kalori HALAL',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '86 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original (75gr)',
#   'price': 'Rp20.200',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Tom Yum 73gr - Mie Shirataki - Mie Diet - Rendah Kalori',
#   'price': 'Rp27.400\nRp23.900',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '50 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp19.878 - Rp20.278',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '281 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'FITMEE MIE SHIRATAKI GORENG KOREA SAPI SOTO CARBONARA AYAM BAWANG FITME MI SIRATAKI KONYAKU FIT MEE ME DIET KETO DEBM MAKANAN ASHITAKI CREAMY LATTE BERAS PORANG RICE KERING BASAH PENURUN BERAT BADAN PELANGSING PRUNES PRUNE PLUM CHIA SEED CIA TEH JATI CINA\nPilih 3, diskon 1%',
#   'price': 'Rp17.900 - Rp19.990',
#   'city': 'KOTA MADIUN',
#   'location': 'KOTA MADIUN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '579 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Ashitaba & Shirataki Mie Instan Rendah Kalori',
#   'price': 'Rp18.000 - Rp20.500',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '425 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mi Rebus Rasa Soto Ashitaki 69.5 g\nMurah Lebay',
#   'price': 'Rp22.900',
#   'city': 'KOTA JAKARTA SELATAN',
#   'location': 'KOTA JAKARTA SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '226 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original',
#   'price': 'Rp19.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '18 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Soto (1 Box)',
#   'price': 'Rp23.000\nRp17.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '558 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Rendang / Tomyum / Kari Ayam',
#   'price': 'Rp19.192 - Rp20.169',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '41 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Noodle / Mie Rendah Carbo / MIE DIET / RENDAH KALORI / MIE SEHAT / LOW FAT / TOM YUM TOMYUM TOMYAM TOM YAM SOTO RENDANG KARI ORIGINAL ALA JEPANG',
#   'price': 'Rp21.500 - Rp21.900',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki MI Goreng Ala Jepang 68 gr',
#   'price': 'Rp21.400\nRp19.000',
#   'city': 'KOTA BALIKPAPAN',
#   'location': 'KOTA BALIKPAPAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Instan Bulgogi 76 gr',
#   'price': 'Rp23.200\nRp19.300',
#   'city': 'KOTA BEKASI',
#   'location': 'KOTA BEKASI',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '168 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Fit mee Mie Shirataki Rasa Mie Goreng Korea',
#   'price': 'Rp15.350',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Rasa Soto',
#   'price': 'Rp19.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '17 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki (Ashitaba & Shirataki) Mi Kari Pedas - 75 g\nGrosir',
#   'price': 'Rp22.000',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '62 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Low Calori - Rendang',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '19 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': '[GROSIR!!] mie Ashitaki Rendah Kalori Diet\nGrosir',
#   'price': 'Rp20.000\nRp18.300',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE INSTAN ASHITABA SHIRATAKI MIE DIET',
#   'price': 'Rp23.000',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '283 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Low Calori - Creamy Sauce\nHadiah Gratis',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '15 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Tomyum Shirataki Mie',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '64 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Rasa Creamy Sauce',
#   'price': 'Rp21.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '12 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Ashitaba Mie Mi Shirataki Noodle Soto Goreng Original Jepang Kari Pedas Creamy Sauce Veggie Bulgogi Halal Diet Instan Sehat Low Rendah Carbo\nDiskon Rp50',
#   'price': 'Rp19.800',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,9RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie',
#   'price': 'Rp22.000',
#   'city': 'KOTA BANJARBARU',
#   'location': 'KOTA BANJARBARU',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Kari Pedas\nHadiah Gratis',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '16 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng/Rebus Instant with Chalcone / Mie Instan Shirataki',
#   'price': 'Rp20.000 - Rp20.500',
#   'city': 'KOTA YOGYAKARTA',
#   'location': 'KOTA YOGYAKARTA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '282 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Jepang 1 DUS ISI 12PCS (12x68gr)',
#   'price': 'Rp227.100',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '22 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original (1 Box)',
#   'price': 'Rp23.000\nRp17.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '426 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN HALAL PROMO BPOM',
#   'price': 'Rp18.499',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi veggie original 67gr- Mie Diet - Mie Tanpa Pengawet',
#   'price': 'Rp24.000',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '32 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mie Ashitaki Diet Rendah Kalori',
#   'price': 'Rp20.000\nRp18.500',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki/ Shirataki soto jepang veggie kari creamy Mug Cake mattcha , chocolate latte Low Callory',
#   'price': 'Rp4.500 - Rp24.000',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Wet Shirataki Noodle (Mie Shirataki Basah) Per-Dus/Carton',
#   'price': 'Rp190.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '189 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mr Ishii Mie Shirataki Basah (200 gr)',
#   'price': 'Rp10.999',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Konnyaku Blok (Shirataki Konnyaku Low Carbs-Ketogenic) 500Gram',
#   'price': 'Rp16.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '539 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Creamy Sauce 85gr (Mie Rendah Kalori)',
#   'price': 'Rp22.700',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '96 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original 75gr (Mie Rendah Kalori)',
#   'price': 'Rp22.700',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '247 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Paket Ashitaki 2',
#   'price': 'Rp99.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '9 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Fitmee - FitMee BAYAM / (Shirataki Noodle) Low Calorie Mie Diet Bebas Kolestrol, Rendah Gula dan Tinggi Serat',
#   'price': 'Rp18.500\nRp18.250',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,8RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Goreng Original 75gr - Mie Tanpa Pengawet\nPilih 3, diskon 3%',
#   'price': 'Rp24.900\nRp23.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,3RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Rebus Soto 75gr - Mie Rendah Kalori\nPilih 3, diskon 3%',
#   'price': 'Rp24.900\nRp23.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,9RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Soto - Goreng Original - Goreng ala Jepang',
#   'price': 'Rp19.240',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN\nCashback 50%',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '3,6RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki mie Rendah Kalori',
#   'price': 'Rp20.000\nRp18.800',
#   'city': 'KOTA DEPOK',
#   'location': 'KOTA DEPOK',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mie Rendah Kalori Shirataki Tanpa Pengawet Mi Goreng Jepang Goreng Original',
#   'price': 'Rp19.053 - Rp39.572',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '90 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT ASHITABA | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp19.790 - Rp20.490',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '10RB+ Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mie Shirataki Diet Sehat | Shirataki Noodle Mie Instant',
#   'price': 'Rp25.000\nRp19.950',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '950 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE GORENG JEPANG ORIGINAL SOTO VEGAN KARI PEDAS BULGOGI CREAMY SAUCE SHIRATAKI ASHITABA MI SIRATAKI DIET KONYAKU NASI BERAS SIRATAKI PORANG BASAH KERING RICE NOODLE DEBM KETO PENURUN BERAT BADAN PELANGSING PRUNE PLUM CHIA SEED FITMEE FITME CIA\nPilih 3, diskon 1%',
#   'price': 'Rp30.000\nRp19.900',
#   'city': 'KOTA MADIUN',
#   'location': 'KOTA MADIUN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp18.499',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mie Low Callories Ashitaki Ashitaba Shirataki',
#   'price': 'Rp19.800',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '350 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Instan (Ashitaba & Shirataki)',
#   'price': 'Rp18.490 - Rp18.990',
#   'city': 'KOTA BANDUNG',
#   'location': 'KOTA BANDUNG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '10RB+ Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Shirataki Instant Diet',
#   'price': 'Rp24.999\nRp24.599',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '439 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Instan Ashitaba Shirataki 68 gram',
#   'price': 'Rp18.500',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '504 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Shirataki Rebus Soto / Kari Ayam - Instanst sehat NON MSG low carbo diet keto',
#   'price': 'Rp18.700',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mi Rebus Shirataki Soto - Diet Keto Non MSG',
#   'price': 'Rp18.780',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '196 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original 1 DUS ISI 12PCS (12x75gr)',
#   'price': 'Rp227.100',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '65 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Kari Ayam',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mie Shirataki - Mi Instan Diet Sehat - Ashitaba Konjac Noodle - Rendah Kalori',
#   'price': 'Rp19.900 - Rp20.400',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '283 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Tomyum',
#   'price': 'Rp22.000',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '56 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mie Instant Ashitaba Ashitaki',
#   'price': 'Rp19.500',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '88 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Rendang Shirataki Diet Rendah Kalori HALAL',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '86 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original (75gr)',
#   'price': 'Rp20.200',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Tom Yum 73gr - Mie Shirataki - Mie Diet - Rendah Kalori',
#   'price': 'Rp27.400\nRp23.900',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '50 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp19.878 - Rp20.278',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '281 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'FITMEE MIE SHIRATAKI GORENG KOREA SAPI SOTO CARBONARA AYAM BAWANG FITME MI SIRATAKI KONYAKU FIT MEE ME DIET KETO DEBM MAKANAN ASHITAKI CREAMY LATTE BERAS PORANG RICE KERING BASAH PENURUN BERAT BADAN PELANGSING PRUNES PRUNE PLUM CHIA SEED CIA TEH JATI CINA\nPilih 3, diskon 1%',
#   'price': 'Rp17.900 - Rp19.990',
#   'city': 'KOTA MADIUN',
#   'location': 'KOTA MADIUN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '579 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Ashitaba & Shirataki Mie Instan Rendah Kalori',
#   'price': 'Rp18.000 - Rp20.500',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '425 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mi Rebus Rasa Soto Ashitaki 69.5 g\nMurah Lebay',
#   'price': 'Rp22.900',
#   'city': 'KOTA JAKARTA SELATAN',
#   'location': 'KOTA JAKARTA SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '226 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original',
#   'price': 'Rp19.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '18 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Soto (1 Box)',
#   'price': 'Rp23.000\nRp17.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '558 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Rendang / Tomyum / Kari Ayam',
#   'price': 'Rp19.192 - Rp20.169',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '41 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Noodle / Mie Rendah Carbo / MIE DIET / RENDAH KALORI / MIE SEHAT / LOW FAT / TOM YUM TOMYUM TOMYAM TOM YAM SOTO RENDANG KARI ORIGINAL ALA JEPANG',
#   'price': 'Rp21.500 - Rp21.900',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki MI Goreng Ala Jepang 68 gr',
#   'price': 'Rp21.400\nRp19.000',
#   'city': 'KOTA BALIKPAPAN',
#   'location': 'KOTA BALIKPAPAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Instan Bulgogi 76 gr',
#   'price': 'Rp23.200\nRp19.300',
#   'city': 'KOTA BEKASI',
#   'location': 'KOTA BEKASI',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '168 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Fit mee Mie Shirataki Rasa Mie Goreng Korea',
#   'price': 'Rp15.350',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Rasa Soto',
#   'price': 'Rp19.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '17 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki (Ashitaba & Shirataki) Mi Kari Pedas - 75 g\nGrosir',
#   'price': 'Rp22.000',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '62 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Low Calori - Rendang',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '19 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': '[GROSIR!!] mie Ashitaki Rendah Kalori Diet\nGrosir',
#   'price': 'Rp20.000\nRp18.300',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE INSTAN ASHITABA SHIRATAKI MIE DIET',
#   'price': 'Rp23.000',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '283 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Low Calori - Creamy Sauce\nHadiah Gratis',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '15 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Tomyum Shirataki Mie',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '64 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Rasa Creamy Sauce',
#   'price': 'Rp21.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '12 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Ashitaba Mie Mi Shirataki Noodle Soto Goreng Original Jepang Kari Pedas Creamy Sauce Veggie Bulgogi Halal Diet Instan Sehat Low Rendah Carbo\nDiskon Rp50',
#   'price': 'Rp19.800',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,9RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie',
#   'price': 'Rp22.000',
#   'city': 'KOTA BANJARBARU',
#   'location': 'KOTA BANJARBARU',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Kari Pedas\nHadiah Gratis',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '16 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng/Rebus Instant with Chalcone / Mie Instan Shirataki',
#   'price': 'Rp20.000 - Rp20.500',
#   'city': 'KOTA YOGYAKARTA',
#   'location': 'KOTA YOGYAKARTA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '282 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Jepang 1 DUS ISI 12PCS (12x68gr)',
#   'price': 'Rp227.100',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '22 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original (1 Box)',
#   'price': 'Rp23.000\nRp17.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '426 Terjual',
#   'shop_name': ''},
# ...
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Rebus Soto 75gr - Mie Rendah Kalori\nPilih 3, diskon 3%',
#   'price': 'Rp24.900\nRp23.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,9RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Soto - Goreng Original - Goreng ala Jepang',
#   'price': 'Rp19.240',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN\nCashback 50%',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '3,6RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki mie Rendah Kalori',
#   'price': 'Rp20.000\nRp18.800',
#   'city': 'KOTA DEPOK',
#   'location': 'KOTA DEPOK',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mie Rendah Kalori Shirataki Tanpa Pengawet Mi Goreng Jepang Goreng Original',
#   'price': 'Rp19.053 - Rp39.572',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '90 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT ASHITABA | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp19.790 - Rp20.490',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '10RB+ Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mie Shirataki Diet Sehat | Shirataki Noodle Mie Instant',
#   'price': 'Rp25.000\nRp19.950',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '950 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE GORENG JEPANG ORIGINAL SOTO VEGAN KARI PEDAS BULGOGI CREAMY SAUCE SHIRATAKI ASHITABA MI SIRATAKI DIET KONYAKU NASI BERAS SIRATAKI PORANG BASAH KERING RICE NOODLE DEBM KETO PENURUN BERAT BADAN PELANGSING PRUNE PLUM CHIA SEED FITMEE FITME CIA\nPilih 3, diskon 1%',
#   'price': 'Rp30.000\nRp19.900',
#   'city': 'KOTA MADIUN',
#   'location': 'KOTA MADIUN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp18.499',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mie Low Callories Ashitaki Ashitaba Shirataki',
#   'price': 'Rp19.800',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '350 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Instan (Ashitaba & Shirataki)',
#   'price': 'Rp18.490 - Rp18.990',
#   'city': 'KOTA BANDUNG',
#   'location': 'KOTA BANDUNG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '10RB+ Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Shirataki Instant Diet',
#   'price': 'Rp24.999\nRp24.599',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '439 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Instan Ashitaba Shirataki 68 gram',
#   'price': 'Rp18.500',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '504 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Shirataki Rebus Soto / Kari Ayam - Instanst sehat NON MSG low carbo diet keto',
#   'price': 'Rp18.700',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,7RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mi Rebus Shirataki Soto - Diet Keto Non MSG',
#   'price': 'Rp18.780',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '196 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original 1 DUS ISI 12PCS (12x75gr)',
#   'price': 'Rp227.100',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '65 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Kari Ayam',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mie Shirataki - Mi Instan Diet Sehat - Ashitaba Konjac Noodle - Rendah Kalori',
#   'price': 'Rp19.900 - Rp20.400',
#   'city': 'KOTA SURABAYA',
#   'location': 'KOTA SURABAYA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '283 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Tomyum',
#   'price': 'Rp22.000',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '56 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI Mie Instant Ashitaba Ashitaki',
#   'price': 'Rp19.500',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '88 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Rendang Shirataki Diet Rendah Kalori HALAL',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '86 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original (75gr)',
#   'price': 'Rp20.200',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi Tom Yum 73gr - Mie Shirataki - Mie Diet - Rendah Kalori',
#   'price': 'Rp27.400\nRp23.900',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '50 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN',
#   'price': 'Rp19.878 - Rp20.278',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '281 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'FITMEE MIE SHIRATAKI GORENG KOREA SAPI SOTO CARBONARA AYAM BAWANG FITME MI SIRATAKI KONYAKU FIT MEE ME DIET KETO DEBM MAKANAN ASHITAKI CREAMY LATTE BERAS PORANG RICE KERING BASAH PENURUN BERAT BADAN PELANGSING PRUNES PRUNE PLUM CHIA SEED CIA TEH JATI CINA\nPilih 3, diskon 1%',
#   'price': 'Rp17.900 - Rp19.990',
#   'city': 'KOTA MADIUN',
#   'location': 'KOTA MADIUN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '579 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Ashitaba & Shirataki Mie Instan Rendah Kalori',
#   'price': 'Rp18.000 - Rp20.500',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '425 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mi Rebus Rasa Soto Ashitaki 69.5 g\nMurah Lebay',
#   'price': 'Rp22.900',
#   'city': 'KOTA JAKARTA SELATAN',
#   'location': 'KOTA JAKARTA SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '226 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original',
#   'price': 'Rp19.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '18 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Soto (1 Box)',
#   'price': 'Rp23.000\nRp17.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '558 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Rendang / Tomyum / Kari Ayam',
#   'price': 'Rp19.192 - Rp20.169',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '41 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Noodle / Mie Rendah Carbo / MIE DIET / RENDAH KALORI / MIE SEHAT / LOW FAT / TOM YUM TOMYUM TOMYAM TOM YAM SOTO RENDANG KARI ORIGINAL ALA JEPANG',
#   'price': 'Rp21.500 - Rp21.900',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki MI Goreng Ala Jepang 68 gr',
#   'price': 'Rp21.400\nRp19.000',
#   'city': 'KOTA BALIKPAPAN',
#   'location': 'KOTA BALIKPAPAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,1RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Instan Bulgogi 76 gr',
#   'price': 'Rp23.200\nRp19.300',
#   'city': 'KOTA BEKASI',
#   'location': 'KOTA BEKASI',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '168 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Fit mee Mie Shirataki Rasa Mie Goreng Korea',
#   'price': 'Rp15.350',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Rasa Soto',
#   'price': 'Rp19.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '17 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki (Ashitaba & Shirataki) Mi Kari Pedas - 75 g\nGrosir',
#   'price': 'Rp22.000',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '62 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Low Calori - Rendang',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '19 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': '[GROSIR!!] mie Ashitaki Rendah Kalori Diet\nGrosir',
#   'price': 'Rp20.000\nRp18.300',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE INSTAN ASHITABA SHIRATAKI MIE DIET',
#   'price': 'Rp23.000',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '283 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Goreng Low Calori - Creamy Sauce\nHadiah Gratis',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '15 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Rebus Tomyum Shirataki Mie',
#   'price': 'Rp18.999',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '64 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Rasa Creamy Sauce',
#   'price': 'Rp21.900',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '12 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Ashitaba Mie Mi Shirataki Noodle Soto Goreng Original Jepang Kari Pedas Creamy Sauce Veggie Bulgogi Halal Diet Instan Sehat Low Rendah Carbo\nDiskon Rp50',
#   'price': 'Rp19.800',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,9RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie',
#   'price': 'Rp22.000',
#   'city': 'KOTA BANJARBARU',
#   'location': 'KOTA BANJARBARU',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mie Rebus Low Calori - Kari Pedas\nHadiah Gratis',
#   'price': 'Rp22.000\nRp19.100',
#   'city': 'KOTA JAKARTA UTARA',
#   'location': 'KOTA JAKARTA UTARA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '16 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng/Rebus Instant with Chalcone / Mie Instan Shirataki',
#   'price': 'Rp20.000 - Rp20.500',
#   'city': 'KOTA YOGYAKARTA',
#   'location': 'KOTA YOGYAKARTA',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '282 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Jepang 1 DUS ISI 12PCS (12x68gr)',
#   'price': 'Rp227.100',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '22 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original (1 Box)',
#   'price': 'Rp23.000\nRp17.500',
#   'city': 'KOTA JAKARTA PUSAT',
#   'location': 'KOTA JAKARTA PUSAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '426 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI NOODLE MIE INSTAN HALAL PROMO BPOM',
#   'price': 'Rp18.499',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '34 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki - Mi veggie original 67gr- Mie Diet - Mie Tanpa Pengawet',
#   'price': 'Rp24.000',
#   'city': 'KAB. TANGERANG',
#   'location': 'KAB. TANGERANG',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '32 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mie Ashitaki Diet Rendah Kalori',
#   'price': 'Rp20.000\nRp18.500',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '2,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki/ Shirataki soto jepang veggie kari creamy Mug Cake mattcha , chocolate latte Low Callory',
#   'price': 'Rp4.500 - Rp24.000',
#   'city': 'KOTA JAKARTA BARAT',
#   'location': 'KOTA JAKARTA BARAT',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,5RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Wet Shirataki Noodle (Mie Shirataki Basah) Per-Dus/Carton',
#   'price': 'Rp190.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '189 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Mr Ishii Mie Shirataki Basah (200 gr)',
#   'price': 'Rp10.999',
#   'city': 'KOTA MEDAN',
#   'location': 'KOTA MEDAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '1,2RB Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Konnyaku Blok (Shirataki Konnyaku Low Carbs-Ketogenic) 500Gram',
#   'price': 'Rp16.000',
#   'city': 'KOTA TANGERANG SELATAN',
#   'location': 'KOTA TANGERANG SELATAN',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '539 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Creamy Sauce 85gr (Mie Rendah Kalori)',
#   'price': 'Rp22.700',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '96 Terjual',
#   'shop_name': ''},
#  {'img_url': '0',
#   'product_name': 'Ashitaki Mi Goreng Original 75gr (Mie Rendah Kalori)',
#   'price': 'Rp22.700',
#   'city': 'KOTA JAKARTA TIMUR',
#   'location': 'KOTA JAKARTA TIMUR',
#   'rating': '',
#   'url': '',
#   'quantity_sold': '247 Terjual',
#   'shop_name': ''}]

# %%
import pandas as pd 

df = pd.DataFrame(datas) 
df
# Out:
#     img_url                                       product_name  \
# 0         0                                   Paket Ashitaki 2
# 1         0  Fitmee - FitMee BAYAM / (Shirataki Noodle) Low...
# 2         0  Ashitaki - Mi Goreng Original 75gr - Mie Tanpa...
# 3         0  Ashitaki - Mi Rebus Soto 75gr - Mie Rendah Kal...
# 4         0  Ashitaki Mie Rebus Soto - Goreng Original - Go...
# ..      ...                                                ...
# 715       0  Wet Shirataki Noodle (Mie Shirataki Basah) Per...
# 716       0              Mr Ishii Mie Shirataki Basah (200 gr)
# 717       0  Konnyaku Blok (Shirataki Konnyaku Low Carbs-Ke...
# 718       0  Ashitaki Mi Goreng Creamy Sauce 85gr (Mie Rend...
# 719       0  Ashitaki Mi Goreng Original 75gr (Mie Rendah K...
#
#                   price                    city                location  \
# 0              Rp99.000  KOTA TANGERANG SELATAN  KOTA TANGERANG SELATAN
# 1    Rp18.500\nRp18.250  KOTA TANGERANG SELATAN  KOTA TANGERANG SELATAN
# 2    Rp24.900\nRp23.500      KOTA JAKARTA PUSAT      KOTA JAKARTA PUSAT
# 3    Rp24.900\nRp23.500      KOTA JAKARTA PUSAT      KOTA JAKARTA PUSAT
# 4              Rp19.240      KOTA JAKARTA TIMUR      KOTA JAKARTA TIMUR
# ..                  ...                     ...                     ...
# 715           Rp190.000  KOTA TANGERANG SELATAN  KOTA TANGERANG SELATAN
# 716            Rp10.999              KOTA MEDAN              KOTA MEDAN
# 717            Rp16.000  KOTA TANGERANG SELATAN  KOTA TANGERANG SELATAN
# 718            Rp22.700      KOTA JAKARTA TIMUR      KOTA JAKARTA TIMUR
# 719            Rp22.700      KOTA JAKARTA TIMUR      KOTA JAKARTA TIMUR
#
#     rating url  quantity_sold shop_name
# 0                   9 Terjual
# 1               1,8RB Terjual
# 2               2,3RB Terjual
# 3               1,9RB Terjual
# 4               1,7RB Terjual
# ..     ...  ..            ...       ...
# 715               189 Terjual
# 716             1,2RB Terjual
# 717               539 Terjual
# 718                96 Terjual
# 719               247 Terjual
#
# [720 rows x 9 columns]

# %%
df['quantity_sold'] = df['quantity_sold'].replace(to_replace =['Terjual','\+'], value = '', regex = True)
df['quantity_sold']
# Out:
# 0          9
# 1      1,8RB
# 2      2,3RB
# 3      1,9RB
# 4      1,7RB
#         ...
# 715      189
# 716    1,2RB
# 717      539
# 718       96
# 719      247
# Name: quantity_sold, Length: 720, dtype: object

# %%
#create new column that checks if each team name contains 'Good' or 'East'
df['good_or_east'] = df['quantity_sold'].str.contains('|'.join(['RB', '\,']))

#view updated DataFrame
df['good_or_east']
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 715    False
# 716     True
# 717    False
# 718    False
# 719    False
# Name: good_or_east, Length: 720, dtype: bool

# %%
#create new column that checks if each team name contains 'Good' or 'East'
df['good_or_east2'] = df['quantity_sold'].str.contains( '\,'))

#view updated DataFrame
df['good_or_east2']

# %%
import pandas as pd 

df = pd.DataFrame(datas) 

df['quantity_sold'] = df['quantity_sold'].replace(to_replace =['Terjual','\+'], value = '', regex = True)
df['quantity_sold'] = df['quantity_sold'].replace(to_replace =['RB'], value = '00', regex = True)
df['quantity_sold'] = df['quantity_sold'].replace(to_replace =['\,'], value = '', regex = True)
#df['quantity_sold'] = df['quantity_sold'].astype(int) #assign tipe data integer
df['quantity_sold']
# Out:
# 0         9
# 1      2200
# 2      2300
# 3      1800
# 4      1700
#        ...
# 715    1900
# 716    1200
# 717     247
# 718      96
# 719     189
# Name: quantity_sold, Length: 720, dtype: object

# %%
import pandas as pd 

df = pd.DataFrame(datas) 

df['quantity_sold'] = df['quantity_sold'].replace(to_replace =['Terjual','\+'], value = '', regex = True)
df['quantity_sold'] = df['quantity_sold'].replace(to_replace =['RB'], value = '00', regex = True)
df['quantity_sold'] = df['quantity_sold'].replace(to_replace =['\,'], value = '', regex = True)
#df['quantity_sold'] = df['quantity_sold'].astype(int) #assign tipe data integer


df['price'] = df['price'].replace(to_replace =['Rp','\.'], value = '', regex = True)
df['price']
# saving the dataframe 
file_name = keyword + "_" + market_place + "_" + date_str + "_" + time_str +'1.csv'
print(file_name)
df.to_csv(file_name)
# Out:
# mie ashitaki_shopee_15Jan23_19401.csv

# %%
df
# Out:
#                                                 img_url  \
# 0     https://images.tokopedia.net/img/cache/200-squ...
# 1     https://images.tokopedia.net/img/cache/200-squ...
# 2     https://images.tokopedia.net/img/cache/200-squ...
# 3     https://images.tokopedia.net/img/cache/200-squ...
# 4     https://images.tokopedia.net/img/cache/200-squ...
# ...                                                 ...
# 3977  https://images.tokopedia.net/img/cache/200-squ...
# 3978  https://images.tokopedia.net/img/cache/200-squ...
# 3979  https://images.tokopedia.net/img/cache/200-squ...
# 3980  https://images.tokopedia.net/img/cache/200-squ...
# 3981  https://images.tokopedia.net/img/cache/200-squ...
#
#                                            product_name   price  \
# 0     Ashitaki - Mie Shirataki Diet Sehat | Shiratak...   19950
# 1                            mie Ashitaki Rendah Kalori   18600
# 2     ASHITAKI MIE SHIRATAKI DIET SEHAT | SHIRATAKI ...   17999
# 3     Ashitaki - Mie Instant Sehat Rendah Kalori Die...   19900
# 4     Ashitaki - Mi Goreng Ala Jepang 69 gr - Mie Re...   18500
# ...                                                 ...     ...
# 3977                        Ashitaki Mi Rebus Rasa Soto   19900
# 3978             Ashitaki Mi Rebus Tomyum Shirataki Mie   18999
# 3979             Ashitaki Mi Goreng Original (1 Karton)  276000
# 3980                            Ashitaki Mie Kari Pedas   23600
# 3981       Ashitaki Mi Rebus Tomyum Shirataki Mie HALAL   18999
#
#                     city            location rating url  quantity_sold  \
# 0      Tangerang Selatan   Tangerang Selatan    4.9  Ad            750
# 1                  Depok               Depok    4.8  Ad           2000
# 2         Kab. Tangerang      Kab. Tangerang    4.9  Ad          10000
# 3         Kab. Tangerang      Kab. Tangerang    5.0  Ad           1000
# 4         Kab. Tangerang      Kab. Tangerang    5.0  Ad            100
# ...                  ...                 ...    ...  ..            ...
# 3977   Tangerang Selatan   Tangerang Selatan    5.0  Ad             30
# 3978      Kab. Tangerang      Kab. Tangerang    5.0  Ad             14
# 3979       Jakarta Pusat       Jakarta Pusat    4.6  Ad             50
# 3980  Dilayani Tokopedia  Dilayani Tokopedia    5.0  Ad              4
# 3981      Kab. Tangerang      Kab. Tangerang    4.8  Ad            100
#
#                     shop_name
# 0               Toko Telur ID
# 1                       madoe
# 2            Rumah Baking TBK
# 3                Yellowfields
# 4                  Somura TBK
# ...                       ...
# 3977          Beeru Indonesia
# 3978               KAIA Shops
# 3979    Nutragen Global Esana
# 3980  Topserba Official Store
# 3981               Somura TBK
#
# [3982 rows x 9 columns]
